# %%
import numpy as np
import pandas as pd
from sklearn.manifold import TSNE

# %%
image_array = np.load("../data/image_cluster/image.npy")

# %%
image_array.shape
# Out:
# (140000, 784)

# %%
test_case_df = pd.read_csv("../data/image_cluster/test_case.csv", header=0)

# %%
test_case_df
# Out:
#               ID  image1_index  image2_index
# 0              0         17874         20452
# 1              1         19897        107188
# 2              2         68922         34890
# 3              3         36315         96063
# 4              4         62858         20570
# 5              5         34857        103021
# 6              6         95637         11993
# 7              7         42482        127374
# 8              8         64230         13878
# 9              9         20777         80492
# 10            10         74558         15315
# 11            11         11761        109393
# 12            12         53550        118766
# 13            13         37756         59298
# 14            14         82624         49316
# 15            15          3201        109547
# 16            16         53359        109705
# 17            17         46248         67774
# 18            18         56236          3535
# 19            19         41362        109531
# ...
